# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import os

# %%
alg_dict = {'sort': 'bubble_sort'}

# %%
def make_df(filename):
    df = pd.read_csv(f'csv/{filename}')
    df = df.set_index('filename')
    del df['Unnamed: 0']
    return df

# %%
df_bubble_sort = make_df('buble_sort.csv')

# %%
# %cd dataset_bubble_sort
for index, row in df_bubble_sort.iterrows():
    with open(str(index),'r', encoding = 'utf-8') as file:
        print(file.read())
# %cd ..
# Out:
# C:\Users\Matvey\Анализ кода\dataset_bubble_sort
# def bubble_sort(list1):
#     has_swapped = True
#
#     total_iteration = 0
#
#     while (has_swapped):
#         has_swapped = False
#         for i in range(len(list1) - total_iteration - 1):
#             if list1[i] > list1[i + 1]:
#                 # Swap
#                 list1[i], list1[i + 1] = list1[i + 1], list1[i]
#                 has_swapped = True
#         total_iteration += 1
#     print("The number of iteraton: ", total_iteration)
#     return list1
#
#
# def bubble_sort(list1):
#     # We can stop the iteration once the swap has done
#     has_swapped = True
#
#     while (has_swapped):
#         has_swapped = False
#         for i in range(len(list1) - 1):
#             if list1[i] > list1[i + 1]:
#                 # Swap
#                 list1[i], list1[i + 1] = list1[i + 1], list1[i]
#                 has_swapped = True
#     return list1
#
# def bubble_sort(list1):
# ...

# %%
# Out:
# C:\Users\Matvey\Анализ кода
