# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
from os import chdir
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, LSTM, Embedding

from sklearn.model_selection import train_test_split

from IPython.display import clear_output

# %%
#планируется словарь алгоритмов для более быстрого создания всех датафреймов
alg_dict = {'sort': ['bubble_sort', 'quicksort'], 'find': ['binary_search']}

# %%
#создание датафрейма
def make_df():
    df = pd.read_csv(f'csv/dataset.csv')
    df = df.set_index('filename')
    del df['Unnamed: 0']
    return df

# %%
def classification_sort(df):
    df = df[df['algorithm'] == 'sort']
    sort_class = []
    for language,algorithm,algorithm_name in zip(df['language'],df['algorithm'],df['algorithm_name']):
        if algorithm_name == 'bubble_sort':
            sort_class.append([1,0])
        else:
            sort_class.append([0,1])
    return df, sort_class

# %%
def classification_find(df):
    df = df[df['algorithm'] == 'find']
    sort_class = []
    for language,algorithm,algorithm_name in zip(df['language'],df['algorithm'],df['algorithm_name']):
        if algorithm_name == 'bubble_sort':
            sort_class.append([1,0])
        else:
            sort_class.append([0,1])
    return df, sort_class

# %%
def file_read(df):
    new_lines = []
    #df = df.sort_values(by='filename')
    for index, row in df.iterrows():
        chdir(f'dataset/{row[1]}/{row[2]}')
        with open(str(index),'r', encoding = 'utf-8') as f:
            lines = f.readlines()
            lines = [line for line in lines if line.strip() != ""]
        # %cd ../../..
        new_lines.append(lines)
    #%cd ../..
    return new_lines

# %%
#обработка переменной без табов, заменяя их на 2 пробела (Доработать)
def preporcessing_files(lines):
    new_lines = []
    code_line = ''
    for i in lines:
        for j in i:
            j = j.replace('    ', ' ')
            code_line += j
        new_lines.append(code_line)
    return new_lines

# %%
df = make_df()
df_sort, classes_sort = classification_sort(df)
#df_find, classes_find = classification_find(df)
files = file_read(df_sort)
pre_files = preporcessing_files(files)
clear_output()

# %%
pre_files
# Out:
# ['def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\n',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\n',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\n',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\n',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\n',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\n',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arr',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arrdef bubble_sort(arr):\n n = len(arr)\n last_swap = n-1\n while last_swap > 0:\n  new_last_swap = 0\n  for i in range(last_swap):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    new_last_swap = i\n  last_swap = new_last_swap\n return arr',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arrdef bubble_sort(arr):\n n = len(arr)\n last_swap = n-1\n while last_swap > 0:\n  new_last_swap = 0\n  for i in range(last_swap):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    new_last_swap = i\n  last_swap = new_last_swap\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  is_sorted = True\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n  n -= 1\n return arr',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arrdef bubble_sort(arr):\n n = len(arr)\n last_swap = n-1\n while last_swap > 0:\n  new_last_swap = 0\n  for i in range(last_swap):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    new_last_swap = i\n  last_swap = new_last_swap\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  is_sorted = True\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n  n -= 1\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  swaps = 0\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    swaps += 1\n  if swaps == 0:\n   break\n return arr',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arrdef bubble_sort(arr):\n n = len(arr)\n last_swap = n-1\n while last_swap > 0:\n  new_last_swap = 0\n  for i in range(last_swap):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    new_last_swap = i\n  last_swap = new_last_swap\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  is_sorted = True\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n  n -= 1\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  swaps = 0\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    swaps += 1\n  if swaps == 0:\n   break\n return arrdef bubble_sort(arr, max_passes):\n n = len(arr)\n for i in range(min(max_passes, n-1)):\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n return arr',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arrdef bubble_sort(arr):\n n = len(arr)\n last_swap = n-1\n while last_swap > 0:\n  new_last_swap = 0\n  for i in range(last_swap):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    new_last_swap = i\n  last_swap = new_last_swap\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  is_sorted = True\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n  n -= 1\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  swaps = 0\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    swaps += 1\n  if swaps == 0:\n   break\n return arrdef bubble_sort(arr, max_passes):\n n = len(arr)\n for i in range(min(max_passes, n-1)):\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n    N = len(arr)\n if N == 1:\n  return arr\n for i in range(N-1):\n  if arr[i] > arr[i+1]:\n\t  arr[i], arr[i+1] = arr[i+1], arr[i]\n return bubble_sort(arr, N-1)',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arrdef bubble_sort(arr):\n n = len(arr)\n last_swap = n-1\n while last_swap > 0:\n  new_last_swap = 0\n  for i in range(last_swap):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    new_last_swap = i\n  last_swap = new_last_swap\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  is_sorted = True\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n  n -= 1\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  swaps = 0\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    swaps += 1\n  if swaps == 0:\n   break\n return arrdef bubble_sort(arr, max_passes):\n n = len(arr)\n for i in range(min(max_passes, n-1)):\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n    N = len(arr)\n if N == 1:\n  return arr\n for i in range(N-1):\n  if arr[i] > arr[i+1]:\n\t  arr[i], arr[i+1] = arr[i+1], arr[i]\n return bubble_sort(arr, N-1)def bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  is_swapped = False\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n    is_swapped = True\n  if not is_swapped:\n   break\n return arr',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arrdef bubble_sort(arr):\n n = len(arr)\n last_swap = n-1\n while last_swap > 0:\n  new_last_swap = 0\n  for i in range(last_swap):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    new_last_swap = i\n  last_swap = new_last_swap\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  is_sorted = True\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n  n -= 1\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  swaps = 0\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    swaps += 1\n  if swaps == 0:\n   break\n return arrdef bubble_sort(arr, max_passes):\n n = len(arr)\n for i in range(min(max_passes, n-1)):\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n    N = len(arr)\n if N == 1:\n  return arr\n for i in range(N-1):\n  if arr[i] > arr[i+1]:\n\t  arr[i], arr[i+1] = arr[i+1], arr[i]\n return bubble_sort(arr, N-1)def bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  is_swapped = False\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n    is_swapped = True\n  if not is_swapped:\n   break\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n  N = len(arr)\n if N == 1:\n  return arr\n for i in range(N - 1):\n  if arr[i] > arr[i + 1]:\n   arr[i], arr[i + 1] = arr[i + 1], arr[i]\n return bubble_sort(arr, N - 1)',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arrdef bubble_sort(arr):\n n = len(arr)\n last_swap = n-1\n while last_swap > 0:\n  new_last_swap = 0\n  for i in range(last_swap):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    new_last_swap = i\n  last_swap = new_last_swap\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  is_sorted = True\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n  n -= 1\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  swaps = 0\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    swaps += 1\n  if swaps == 0:\n   break\n return arrdef bubble_sort(arr, max_passes):\n n = len(arr)\n for i in range(min(max_passes, n-1)):\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n    N = len(arr)\n if N == 1:\n  return arr\n for i in range(N-1):\n  if arr[i] > arr[i+1]:\n\t  arr[i], arr[i+1] = arr[i+1], arr[i]\n return bubble_sort(arr, N-1)def bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  is_swapped = False\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n    is_swapped = True\n  if not is_swapped:\n   break\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n  N = len(arr)\n if N == 1:\n  return arr\n for i in range(N - 1):\n  if arr[i] > arr[i + 1]:\n   arr[i], arr[i + 1] = arr[i + 1], arr[i]\n return bubble_sort(arr, N - 1)def bubble_sort(arr, comparison_key=lambda x: x):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if comparison_key(arr[j]) > comparison_key(arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arrdef bubble_sort(arr):\n n = len(arr)\n last_swap = n-1\n while last_swap > 0:\n  new_last_swap = 0\n  for i in range(last_swap):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    new_last_swap = i\n  last_swap = new_last_swap\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  is_sorted = True\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n  n -= 1\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  swaps = 0\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    swaps += 1\n  if swaps == 0:\n   break\n return arrdef bubble_sort(arr, max_passes):\n n = len(arr)\n for i in range(min(max_passes, n-1)):\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n    N = len(arr)\n if N == 1:\n  return arr\n for i in range(N-1):\n  if arr[i] > arr[i+1]:\n\t  arr[i], arr[i+1] = arr[i+1], arr[i]\n return bubble_sort(arr, N-1)def bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  is_swapped = False\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n    is_swapped = True\n  if not is_swapped:\n   break\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n  N = len(arr)\n if N == 1:\n  return arr\n for i in range(N - 1):\n  if arr[i] > arr[i + 1]:\n   arr[i], arr[i + 1] = arr[i + 1], arr[i]\n return bubble_sort(arr, N - 1)def bubble_sort(arr, comparison_key=lambda x: x):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if comparison_key(arr[j]) > comparison_key(arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n for i in range(N-1):\n  is_sorted = True\n  for j in range(N-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n return arr',
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arrdef bubble_sort(arr):\n n = len(arr)\n last_swap = n-1\n while last_swap > 0:\n  new_last_swap = 0\n  for i in range(last_swap):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    new_last_swap = i\n  last_swap = new_last_swap\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  is_sorted = True\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n  n -= 1\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  swaps = 0\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    swaps += 1\n  if swaps == 0:\n   break\n return arrdef bubble_sort(arr, max_passes):\n n = len(arr)\n for i in range(min(max_passes, n-1)):\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n    N = len(arr)\n if N == 1:\n  return arr\n for i in range(N-1):\n  if arr[i] > arr[i+1]:\n\t  arr[i], arr[i+1] = arr[i+1], arr[i]\n return bubble_sort(arr, N-1)def bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  is_swapped = False\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n    is_swapped = True\n  if not is_swapped:\n   break\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n  N = len(arr)\n if N == 1:\n  return arr\n for i in range(N - 1):\n  if arr[i] > arr[i + 1]:\n   arr[i], arr[i + 1] = arr[i + 1], arr[i]\n return bubble_sort(arr, N - 1)def bubble_sort(arr, comparison_key=lambda x: x):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if comparison_key(arr[j]) > comparison_key(arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n for i in range(N-1):\n  is_sorted = True\n  for j in range(N-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  has_swapped = False\n  ...
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arrdef bubble_sort(arr):\n n = len(arr)\n last_swap = n-1\n while last_swap > 0:\n  new_last_swap = 0\n  for i in range(last_swap):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    new_last_swap = i\n  last_swap = new_last_swap\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  is_sorted = True\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n  n -= 1\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  swaps = 0\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    swaps += 1\n  if swaps == 0:\n   break\n return arrdef bubble_sort(arr, max_passes):\n n = len(arr)\n for i in range(min(max_passes, n-1)):\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n    N = len(arr)\n if N == 1:\n  return arr\n for i in range(N-1):\n  if arr[i] > arr[i+1]:\n\t  arr[i], arr[i+1] = arr[i+1], arr[i]\n return bubble_sort(arr, N-1)def bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  is_swapped = False\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n    is_swapped = True\n  if not is_swapped:\n   break\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n  N = len(arr)\n if N == 1:\n  return arr\n for i in range(N - 1):\n  if arr[i] > arr[i + 1]:\n   arr[i], arr[i + 1] = arr[i + 1], arr[i]\n return bubble_sort(arr, N - 1)def bubble_sort(arr, comparison_key=lambda x: x):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if comparison_key(arr[j]) > comparison_key(arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n for i in range(N-1):\n  is_sorted = True\n  for j in range(N-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  has_swapped = False\n  ...
# ...
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arrdef bubble_sort(arr):\n n = len(arr)\n last_swap = n-1\n while last_swap > 0:\n  new_last_swap = 0\n  for i in range(last_swap):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    new_last_swap = i\n  last_swap = new_last_swap\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  is_sorted = True\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n  n -= 1\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  swaps = 0\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    swaps += 1\n  if swaps == 0:\n   break\n return arrdef bubble_sort(arr, max_passes):\n n = len(arr)\n for i in range(min(max_passes, n-1)):\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n    N = len(arr)\n if N == 1:\n  return arr\n for i in range(N-1):\n  if arr[i] > arr[i+1]:\n\t  arr[i], arr[i+1] = arr[i+1], arr[i]\n return bubble_sort(arr, N-1)def bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  is_swapped = False\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n    is_swapped = True\n  if not is_swapped:\n   break\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n  N = len(arr)\n if N == 1:\n  return arr\n for i in range(N - 1):\n  if arr[i] > arr[i + 1]:\n   arr[i], arr[i + 1] = arr[i + 1], arr[i]\n return bubble_sort(arr, N - 1)def bubble_sort(arr, comparison_key=lambda x: x):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if comparison_key(arr[j]) > comparison_key(arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n for i in range(N-1):\n  is_sorted = True\n  for j in range(N-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  has_swapped = False\n  ...
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arrdef bubble_sort(arr):\n n = len(arr)\n last_swap = n-1\n while last_swap > 0:\n  new_last_swap = 0\n  for i in range(last_swap):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    new_last_swap = i\n  last_swap = new_last_swap\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  is_sorted = True\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n  n -= 1\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  swaps = 0\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    swaps += 1\n  if swaps == 0:\n   break\n return arrdef bubble_sort(arr, max_passes):\n n = len(arr)\n for i in range(min(max_passes, n-1)):\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n    N = len(arr)\n if N == 1:\n  return arr\n for i in range(N-1):\n  if arr[i] > arr[i+1]:\n\t  arr[i], arr[i+1] = arr[i+1], arr[i]\n return bubble_sort(arr, N-1)def bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  is_swapped = False\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n    is_swapped = True\n  if not is_swapped:\n   break\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n  N = len(arr)\n if N == 1:\n  return arr\n for i in range(N - 1):\n  if arr[i] > arr[i + 1]:\n   arr[i], arr[i + 1] = arr[i + 1], arr[i]\n return bubble_sort(arr, N - 1)def bubble_sort(arr, comparison_key=lambda x: x):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if comparison_key(arr[j]) > comparison_key(arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n for i in range(N-1):\n  is_sorted = True\n  for j in range(N-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  has_swapped = False\n  ...
#  'def bubble_sort(arr):\n has_swapped = True\n total_iteration = 0\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - total_iteration - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n  total_iteration += 1\n return arr\ndef bubble_sort(arr):\n has_swapped = True\n while (has_swapped):\n  has_swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    has_swapped = True\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arr\ndef bubble_sort(arr):\n for i in range(0, len(arr) - 1):\n  for j in range(len(arr) - 1):\n   if (arr[j] > arr[j + 1]):\n    temp = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = temp\n return arr\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    buff = arr[j]\n    arr[j] = arr[j + 1]\n    arr[j + 1] = buff\ndef bubble_sort(arr,N):\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\ndef bubble_sort(arr):\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(len(arr) - 1):\n   if arr[i] > arr[i + 1]:\n    arr[i], arr[i + 1] = arr[i + 1], arr[i]\n    swapped = True\ndef bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n swapped = True\n while swapped:\n  swapped = False\n  for i in range(N-1):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    swapped = True\n return arrdef bubble_sort(arr):\n n = len(arr)\n last_swap = n-1\n while last_swap > 0:\n  new_last_swap = 0\n  for i in range(last_swap):\n   if arr[i] > arr[i+1]:\n    arr[i], arr[i+1] = arr[i+1], arr[i]\n    new_last_swap = i\n  last_swap = new_last_swap\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  is_sorted = True\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n  n -= 1\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  swaps = 0\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    swaps += 1\n  if swaps == 0:\n   break\n return arrdef bubble_sort(arr, max_passes):\n n = len(arr)\n for i in range(min(max_passes, n-1)):\n  for j in range(n-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n    N = len(arr)\n if N == 1:\n  return arr\n for i in range(N-1):\n  if arr[i] > arr[i+1]:\n\t  arr[i], arr[i+1] = arr[i+1], arr[i]\n return bubble_sort(arr, N-1)def bubble_sort(arr):\n N = len(arr)\n for i in range(N - 1):\n  is_swapped = False\n  for j in range(N - i - 1):\n   if arr[j] > arr[j + 1]:\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n    is_swapped = True\n  if not is_swapped:\n   break\n return arrdef bubble_sort(arr, N=None):\n if N is None:\n  N = len(arr)\n if N == 1:\n  return arr\n for i in range(N - 1):\n  if arr[i] > arr[i + 1]:\n   arr[i], arr[i + 1] = arr[i + 1], arr[i]\n return bubble_sort(arr, N - 1)def bubble_sort(arr, comparison_key=lambda x: x):\n N = len(arr)\n for i in range(N - 1):\n  for j in range(N - i - 1):\n   if comparison_key(arr[j]) > comparison_key(arr[j + 1]):\n    arr[j], arr[j + 1] = arr[j + 1], arr[j]\n return arrdef bubble_sort(arr):\n N = len(arr)\n for i in range(N-1):\n  is_sorted = True\n  for j in range(N-i-1):\n   if arr[j] > arr[j+1]:\n    arr[j], arr[j+1] = arr[j+1], arr[j]\n    is_sorted = False\n  if is_sorted:\n   break\n return arrdef bubble_sort(arr):\n n = len(arr)\n for i in range(n-1):\n  has_swapped = False\n  ...

# %% [markdown]
# # Основная часть, построение архитектуры

# %%
maxWord = 1000
max_text_len = 50
tokenizer = Tokenizer(num_words=maxWord, lower = True, split = ' ', char_level=False)
tokenizer.fit_on_texts(pre_file)
dist = list(tokenizer.word_counts.items())
data = tokenizer.texts_to_sequences(pre_files)
data_pad = pad_sequences(data,maxlen = max_text_len)

# %%
X = data_pad
Y = np.array(classes_sort)

# %%
model = Sequential([
    Embedding(maxWord, 128, input_length =max_text_len),
    LSTM(128, return_sequences=True),
    LSTM(64),
    Dense(2, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 50, 128)           128000
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50, 128)           131584
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 309,122
# Trainable params: 309,122
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss ='categorical_crossentropy', metrics = ['accuracy'], optimizer = Adam(0.0001))

# %%
train_data, val_data, train_class, val_class = train_test_split(X,Y, test_size=0.2)

# %%
history = model.fit(X,Y, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 32ms/step - loss: 0.6958 - accuracy: 0.2692
# Epoch 2/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6915 - accuracy: 0.6346
# Epoch 3/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6874 - accuracy: 0.8269
# Epoch 4/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6837 - accuracy: 0.8269
# Epoch 5/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6792 - accuracy: 0.8269
# Epoch 6/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6747 - accuracy: 0.8269
# Epoch 7/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6702 - accuracy: 0.8269
# Epoch 8/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6657 - accuracy: 0.8269
# Epoch 9/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6603 - accuracy: 0.8269
# Epoch 10/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6552 - accuracy: 0.8269
# Epoch 11/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6494 - accuracy: 0.8269
# Epoch 12/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6425 - accuracy: 0.8269
# Epoch 13/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.6353 - accuracy: 0.8269
# Epoch 14/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6271 - accuracy: 0.8269
# Epoch 15/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.6175 - accuracy: 0.8269
# Epoch 16/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6078 - accuracy: 0.8269
# Epoch 17/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.5941 - accuracy: 0.8269
# Epoch 18/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5812 - accuracy: 0.8269
# Epoch 19/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5666 - accuracy: 0.8269
# Epoch 20/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5514 - accuracy: 0.8269
# Epoch 21/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5297 - accuracy: 0.8269
# Epoch 22/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5122 - accuracy: 0.8269
# Epoch 23/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4958 - accuracy: 0.8269
# Epoch 24/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4769 - accuracy: 0.8269
# Epoch 25/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4587 - accuracy: 0.8269
# Epoch 26/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4527 - accuracy: 0.8269
# Epoch 27/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4491 - accuracy: 0.8269
# Epoch 28/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4542 - accuracy: 0.8269
# Epoch 29/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4497 - accuracy: 0.8269
# Epoch 30/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4416 - accuracy: 0.8269
# Epoch 31/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4323 - accuracy: 0.8269
# Epoch 32/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4233 - accuracy: 0.8269
# Epoch 33/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4206 - accuracy: 0.8269
# Epoch 34/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4147 - accuracy: 0.8269
# Epoch 35/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4095 - accuracy: 0.8269
# Epoch 36/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4047 - accuracy: 0.8269
# Epoch 37/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3996 - accuracy: 0.8269
# Epoch 38/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3930 - accuracy: 0.8269
# Epoch 39/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3867 - accuracy: 0.8269
# Epoch 40/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3777 - accuracy: 0.8269
# Epoch 41/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3692 - accuracy: 0.8269
# Epoch 42/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3607 - accuracy: 0.8269
# Epoch 43/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3525 - accuracy: 0.8269
# Epoch 44/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3444 - accuracy: 0.8269
# Epoch 45/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3342 - accuracy: 0.8269
# Epoch 46/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3221 - accuracy: 0.8269
# Epoch 47/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3123 - accuracy: 0.8269
# Epoch 48/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2999 - accuracy: 0.8269
# Epoch 49/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2868 - accuracy: 0.8269
# Epoch 50/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2723 - accuracy: 0.8269
# Epoch 51/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2543 - accuracy: 0.8269
# Epoch 52/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2376 - accuracy: 0.8269
# Epoch 53/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2161 - accuracy: 0.8269
# Epoch 54/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1958 - accuracy: 0.8269
# Epoch 55/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1766 - accuracy: 0.9038
# Epoch 56/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1554 - accuracy: 0.9423
# Epoch 57/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1366 - accuracy: 0.9808
# Epoch 58/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1234 - accuracy: 0.9808
# Epoch 59/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1050 - accuracy: 1.0000
# Epoch 60/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0956 - accuracy: 0.9808
# Epoch 61/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0870 - accuracy: 0.9808
# Epoch 62/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0826 - accuracy: 0.9808
# Epoch 63/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0782 - accuracy: 0.9808
# Epoch 64/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0730 - accuracy: 0.9808
# Epoch 65/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0700 - accuracy: 0.9808
# Epoch 66/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0641 - accuracy: 0.9808
# Epoch 67/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0592 - accuracy: 0.9808
# Epoch 68/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0578 - accuracy: 0.9808
# Epoch 69/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0514 - accuracy: 1.0000
# Epoch 70/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0457 - accuracy: 1.0000
# Epoch 71/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 72/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 73/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 74/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 75/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 76/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 77/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 78/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 79/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 80/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 81/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 82/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 83/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 84/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 85/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 86/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 87/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 88/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 89/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 90/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 91/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 92/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 93/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 94/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 95/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 96/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 97/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 98/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 99/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 100/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0050 - accuracy: 1.0000

# %%
plt.plot(history.history['accuracy'],
         label='обучающий набор')
plt.plot(history.history['val_accuracy'],
         label='проверочный набор')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[161], line 3
#       1 plt.plot(history.history['accuracy'],
#       2          label='обучающий набор')
# ----> 3 plt.plot(history.history['val_accuracy'],
#       4          label='проверочный набор')
#       5 plt.xlabel('Эпоха обучения')
#       6 plt.ylabel('Доля верных ответов')
#
# KeyError: 'val_accuracy'

# %%
reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))
def seqence_to_text(list_of_indices):
    return [reverse_word_map.get(letter) for letter in list_of_indices]

# %%
test_text = """
def bubble_sort(arr):
    swapped = True
    while swapped:
        swapped = False
        for i in range(len(arr) - 1):
            if arr[i] > arr[i + 1]:
                arr[i], arr[i + 1] = arr[i + 1], arr[i]
                swapped = True

            """.lower()
data_test = tokenizer.texts_to_sequences([test_text])
data_pad_test = pad_sequences(data_test, maxlen = max_text_len)
print(seqence_to_text(data_test[0]))
# Out:
# ['def', 'bubble', 'sort', 'arr', 'swapped', 'true', 'while', 'swapped', 'swapped', 'false', 'for', 'i', 'in', 'range', 'len', 'arr', '1', 'if', 'arr', 'i', 'arr', 'i', '1', 'arr', 'i', 'arr', 'i', '1', 'arr', 'i', '1', 'arr', 'i', 'swapped', 'true']

# %%
res = model.predict(data_pad_test)
print(res, np.argmax(res))
# Out:
# [[0.9787067  0.02129326]] 0

# %%
model.save('models\\Первая_адекватная_модель.h5')

# %% [markdown]
# # Вспомогательные функции

# %%
pwd
# Out:
# 'C:\\Users\\Matvey\\Анализ кода\\Code-Insight\\dataset'

# %%
# %cd Анализ кода/Code-Insight
# Out:
# C:\Users\Matvey\Анализ кода\Code-Insight

# %%
# %cd ../..
# Out:
# C:\Users\Matvey\Анализ кода\Code-Insight

# %%
# %cd ../

# %%
# %cd ../../..
