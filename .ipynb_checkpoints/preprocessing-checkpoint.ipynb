# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
from os import chdir
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, LSTM, Embedding, GRU
from tensorflow.keras.layers import Dropout

from sklearn.model_selection import train_test_split

import pickle
from IPython.display import clear_output

# %%
#планируется словарь алгоритмов для более быстрого создания всех датафреймов
alg_dict = {'sort': ['bubble_sort', 'quick_sort','selection_sort','merge_sort'], 'find': ['binary_search']}

# %%
#создание датафрейма
def make_df():
    df = pd.read_csv('csv\dataset_test_4_sort.csv')
    df = df.set_index('filename')
    del df['Unnamed: 0']
    return df

# %%
def classification_sort(df):
    cnt = 0
    df = df[df['algorithm'] == 'sort']
    sort_class = []
    for language,algorithm,algorithm_name in zip(df['language'],df['algorithm'],df['algorithm_name']):
        algorithm_name = algorithm_name.strip()
        if algorithm_name == 'bubble_sort':
            sort_class.append([1,0,0,0])
        if algorithm_name == 'quick_sort':
            sort_class.append([0,1,0,0])
        if algorithm_name == 'selection_sort':
            sort_class.append([0,0,1,0])
        if algorithm_name == 'merge_sort':
            sort_class.append([0,0,0,1])
    return df, np.array(sort_class)

# %%
def classification_find(df):
    df = df[df['algorithm'] == 'find']
    find_class = []
    for language,algorithm,algorithm_name in zip(df['language'],df['algorithm'],df['algorithm_name']):
        algorithm_name = algorithm_name.strip()
        if algorithm_name == 'binary_search':
            find_class.append([1,0])
    return df, find_class

# %%
def file_read(df):
    new_lines = []
    #df = df.sort_values(by='filename')
    for index, row in df.iterrows():
        chdir(f'dataset/{row[1]}/{row[2]}')
        with open(str(index),'r', encoding = 'utf-8') as f:
            lines = f.readlines()
            lines = [line for line in lines if line.strip() != ""]
        # %cd ../../..
        new_lines.append(lines)
    #%cd ../..
    return new_lines

# %%
#обработка переменной без табов, заменяя их на 2 пробела (Доработать)
def preporcessing_files(lines):
    new_lines = []
    code_line = ''
    for i in lines:
        for j in i:
            j = j.replace('    ', ' ')
            code_line += j
        new_lines.append(code_line)
    return new_lines

# %%
df = make_df()

# %%
#Для сортировки
df_sort, classes_sort = classification_sort(df)
files_sort = file_read(df_sort)
pre_files_sort = preporcessing_files(files_sort)
clear_output()

# %%
df_sort
# Out:
#                language algorithm algorithm_name
# filename
# bubble_sort.py       py      sort    bubble_sort
# bubble_sort.py       py      sort    bubble_sort
# bubble_sort.py       py      sort    bubble_sort
# bubble_sort.py       py      sort    bubble_sort
# bubble_sort.py       py      sort    bubble_sort
# ...                 ...       ...            ...
# merge_sort.py        py      sort     merge_sort
# merge_sort.py        py      sort     merge_sort
# merge_sort.py        py      sort     merge_sort
# merge_sort.py        py      sort     merge_sort
# merge_sort.py        py      sort     merge_sort
#
# [216 rows x 3 columns]

# %% [markdown]
# # Основная часть, построение архитектуры

# %%
maxWord = 15
max_text_len = 40
tokenizer = Tokenizer(num_words=maxWord, lower = True, split = ' ', char_level=False)
tokenizer.fit_on_texts(pre_files_sort) #Меняем данные
dist = list(tokenizer.word_counts.items())
data = tokenizer.texts_to_sequences(pre_files_sort) #Меняем данные 
data_pad = pad_sequences(data,maxlen = max_text_len)
X = data_pad
Y = classes_sort

# %%
# with open('files\\4_sort.pickle', 'wb') as file:
#     pickle.dump(pre_files_sort, file)

# %%
len(data_pad) == len(X) == len(Y) == len(pre_files_sort)
# Out:
# True

# %%
model = Sequential([
    Embedding(maxWord, 128, input_length = max_text_len),
    LSTM(32, return_sequences=True),
    LSTM(8),
    Dense(4, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 40, 128)           1920
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 40, 32)            20608
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 8)                 1312
# _________________________________________________________________
# dense_6 (Dense)              (None, 4)                 36
# =================================================================
# Total params: 23,876
# Trainable params: 23,876
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss ='categorical_crossentropy', metrics = ['accuracy'], optimizer = Adam(0.0001))

# %%
train_data, val_data, train_class, val_class = train_test_split(X,Y, test_size=0.2)

# %%
history = model.fit(train_data,train_class, validation_data=(val_data,val_class), batch_size = 512, epochs = 300)
# Out:
# Epoch 1/300
# 1/1 [==============================] - 2s 2s/step - loss: 1.3872 - accuracy: 0.2558 - val_loss: 1.3868 - val_accuracy: 0.2273
# Epoch 2/300
# 1/1 [==============================] - 0s 51ms/step - loss: 1.3864 - accuracy: 0.2558 - val_loss: 1.3861 - val_accuracy: 0.4545
# Epoch 3/300
# 1/1 [==============================] - 0s 56ms/step - loss: 1.3855 - accuracy: 0.5116 - val_loss: 1.3854 - val_accuracy: 0.4545
# Epoch 4/300
# 1/1 [==============================] - 0s 53ms/step - loss: 1.3846 - accuracy: 0.5116 - val_loss: 1.3847 - val_accuracy: 0.4545
# Epoch 5/300
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3838 - accuracy: 0.5116 - val_loss: 1.3840 - val_accuracy: 0.4545
# Epoch 6/300
# 1/1 [==============================] - 0s 61ms/step - loss: 1.3829 - accuracy: 0.5116 - val_loss: 1.3833 - val_accuracy: 0.4545
# Epoch 7/300
# 1/1 [==============================] - 0s 51ms/step - loss: 1.3821 - accuracy: 0.5116 - val_loss: 1.3826 - val_accuracy: 0.4545
# Epoch 8/300
# 1/1 [==============================] - 0s 51ms/step - loss: 1.3812 - accuracy: 0.5116 - val_loss: 1.3818 - val_accuracy: 0.4545
# Epoch 9/300
# 1/1 [==============================] - 0s 51ms/step - loss: 1.3804 - accuracy: 0.5116 - val_loss: 1.3811 - val_accuracy: 0.4545
# Epoch 10/300
# 1/1 [==============================] - 0s 51ms/step - loss: 1.3795 - accuracy: 0.5116 - val_loss: 1.3804 - val_accuracy: 0.4545
# Epoch 11/300
# 1/1 [==============================] - 0s 53ms/step - loss: 1.3787 - accuracy: 0.5116 - val_loss: 1.3797 - val_accuracy: 0.4545
# Epoch 12/300
# 1/1 [==============================] - 0s 47ms/step - loss: 1.3778 - accuracy: 0.5116 - val_loss: 1.3790 - val_accuracy: 0.4545
# Epoch 13/300
# 1/1 [==============================] - 0s 48ms/step - loss: 1.3770 - accuracy: 0.5116 - val_loss: 1.3783 - val_accuracy: 0.4545
# Epoch 14/300
# 1/1 [==============================] - 0s 44ms/step - loss: 1.3761 - accuracy: 0.5116 - val_loss: 1.3775 - val_accuracy: 0.4545
# Epoch 15/300
# 1/1 [==============================] - 0s 45ms/step - loss: 1.3753 - accuracy: 0.5116 - val_loss: 1.3768 - val_accuracy: 0.4545
# Epoch 16/300
# 1/1 [==============================] - 0s 46ms/step - loss: 1.3744 - accuracy: 0.5116 - val_loss: 1.3761 - val_accuracy: 0.4545
# Epoch 17/300
# 1/1 [==============================] - 0s 45ms/step - loss: 1.3735 - accuracy: 0.5116 - val_loss: 1.3753 - val_accuracy: 0.4545
# Epoch 18/300
# 1/1 [==============================] - 0s 45ms/step - loss: 1.3727 - accuracy: 0.5116 - val_loss: 1.3746 - val_accuracy: 0.4545
# Epoch 19/300
# 1/1 [==============================] - 0s 56ms/step - loss: 1.
300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2686 - accuracy: 1.0000 - val_loss: 1.2726 - val_accuracy: 1.0000
# Epoch 94/300
# 1/1 [==============================] - 0s 35ms/step - loss: 1.2661 - accuracy: 1.0000 - val_loss: 1.2701 - val_accuracy: 1.0000
# Epoch 95/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.2635 - accuracy: 1.0000 - val_loss: 1.2675 - val_accuracy: 1.0000
# Epoch 96/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.2609 - accuracy: 1.0000 - val_loss: 1.2648 - val_accuracy: 1.0000
# Epoch 97/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.2583 - accuracy: 1.0000 - val_loss: 1.2621 - val_accuracy: 1.0000
# Epoch 98/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2556 - accuracy: 1.0000 - val_loss: 1.2593 - val_accuracy: 1.0000
# Epoch 99/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2528 - accuracy: 1.0000 - val_loss: 1.2565 - val_accuracy: 1.0000
# Epoch 100/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2500 - accuracy: 1.0000 - val_loss: 1.2536 - val_accuracy: 1.0000
# Epoch 101/300
# 1/1 [==============================] - 0s 38ms/step - loss: 1.2471 - accuracy: 1.0000 - val_loss: 1.2506 - val_accuracy: 1.0000
# Epoch 102/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.2442 - accuracy: 1.0000 - val_loss: 1.2476 - val_accuracy: 1.0000
# Epoch 103/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2412 - accuracy: 1.0000 - val_loss: 1.2445 - val_accuracy: 1.0000
# Epoch 104/300
# 1/1 [==============================] - 0s 35ms/step - loss: 1.2381 - accuracy: 1.0000 - val_loss: 1.2413 - val_accuracy: 1.0000
# Epoch 105/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.2350 - accuracy: 1.0000 - val_loss: 1.2381 - val_accuracy: 1.0000
# Epoch 106/300
# 1/1 [==============================] - 0s 38ms/step - loss: 1.2318 - accuracy: 1.0000 - val_loss: 1.2349 - val_accuracy: 1.0000
# Epoch 107/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.2285 - accuracy: 1.0000 - val_loss: 1.2315 - val_accuracy: 1.0000
# Epoch 108/300
# 1/1 [==============================] - 0s 38ms/step - loss: 1.2252 - accuracy: 1.0000 - val_loss: 1.2281 - val_accuracy: 1.0000
# Epoch 109/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2218 - accuracy: 1.0000 - val_loss: 1.2246 - val_accuracy: 1.0000
# Epoch 110/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2183 - accuracy: 1.0000 - val_loss: 1.2210 - val_accuracy: 1.0000
# Epoch 111/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2148 - accuracy: 1.0000 - val_loss: 1.2173 - val_accuracy: 1.0000
# Epoch 112/300
# 1/1 [==============================] - 0s 38ms/step - loss: 1.2112 - accuracy: 1.0000 - val_loss: 1.2136 - val_accuracy: 1.0000
# Epoch 113/300
# 1/1 [==============================] - 0s 38ms/step - loss: 1.2075 - accuracy: 1.0000 - val_loss: 1.2098 - val_accuracy: 1.0000
# Epoch 114/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2037 - accuracy: 1.0000 - val_loss: 1.2059 - val_accuracy: 1.0000
# Epoch 115/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1999 - accuracy: 1.0000 - val_loss: 1.2020 - val_accuracy: 1.0000
# Epoch 116/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1960 - accuracy: 1.0000 - val_loss: 1.1979 - val_accuracy: 1.0000
# Epoch 117/300
# 1/1 [==============================] - 0s 35ms/step - loss: 1.1920 - accuracy: 1.0000 - val_loss: 1.1938 - val_accuracy: 1.0000
# Epoch 118/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1879 - accuracy: 1.0000 - val_loss: 1.1896 - val_accuracy: 1.0000
# Epoch 119/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1838 - accuracy: 1.0000 - val_loss: 1.1853 - val_accuracy: 1.0000
# Epoch 120/300
# 1/1 [==============================] - 0s 35ms/step - loss: 1.1796 - accuracy: 1.0000 - val_loss: 1.1809 - val_accuracy: 1.0000
# Epoch 121/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1753 - accuracy: 1.0000 - val_loss: 1.1765 - val_accuracy: 1.0000
# Epoch 122/300
# 1/1 [==============================] - 0s 38ms/step - loss: 1.1709 - accuracy: 1.0000 - val_loss: 1.1720 - val_accuracy: 1.0000
# Epoch 123/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1665 - accuracy: 1.0000 - val_loss: 1.1674 - val_accuracy: 1.0000
# Epoch 124/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1620 - accuracy: 1.0000 - val_loss: 1.1627 - val_accuracy: 1.0000
# Epoch 125/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1574 - accuracy: 1.0000 - val_loss: 1.1579 - val_accuracy: 1.0000
# Epoch 126/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1527 - accuracy: 1.0000 - val_loss: 1.1531 - val_accuracy: 1.0000
# Epoch 127/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1480 - accuracy: 1.0000 - val_loss: 1.1481 - val_accuracy: 1.0000
# Epoch 128/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1432 - accuracy: 1.0000 - val_loss: 1.1431 - val_accuracy: 1.0000
# Epoch 129/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1383 - accuracy: 1.0000 - val_loss: 1.1381 - val_accuracy: 1.0000
# Epoch 130/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1334 - accuracy: 1.0000 - val_loss: 1.1329 - val_accuracy: 1.0000
# Epoch 131/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1284 - accuracy: 1.0000 - val_loss: 1.1277 - val_accuracy: 1.0000
# Epoch 132/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1233 - accuracy: 1.0000 - val_loss: 1.1224 - val_accuracy: 1.0000
# Epoch 133/300
# 1/1 [==============================] - 0s 39ms/step - loss: 1.1182 - accuracy: 1.0000 - val_loss: 1.1171 - val_accuracy: 1.0000
# Epoch 134/300
# 1/1 [==============================] - 0s 41ms/step - loss: 1.1130 - accuracy: 1.0000 - val_loss: 1.1118 - val_accuracy: 1.0000
# Epoch 135/300
# 1/1 [==============================] - 0s 40ms/step - loss: 1.1078 - accuracy: 1.0000 - val_loss: 1.1063 - val_accuracy: 1.0000
# Epoch 136/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1026 - accuracy: 1.0000 - val_loss: 1.1008 - val_accuracy: 1.0000
# Epoch 137/300
# 1/1 [==============================] - 0s 36ms/step - loss: 1.0973 - accuracy: 1.0000 - val_loss: 1.0952 - val_accuracy: 1.0000
# Epoch 138/300
# 1/1 [==============================] - 0s 37ms/step - loss: 1.0919 - accuracy: 1.0000 - val_loss: 1.0896 - val_accuracy: 1.0000
# Epoch 139/300
# 1/1 [==============================] - 0s 39ms/step - loss: 1.0865 - accuracy: 1.0000 - val_loss: 1.0840 - val_accuracy: 1.0000
# Epoch 140/300
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0811 - accuracy: 1.0000 - val_loss: 1.0783 - val_accuracy: 1.0000
# Epoch 141/300
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0756 - accuracy: 1.0000 - val_loss: 1.0726 - val_accuracy: 1.0000
# Epoch 142/300
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0701 - accuracy: 1.0000 - val_loss: 1.0668 - val_accuracy: 1.0000
# Epoch 143/300
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0646 - accuracy: 1.0000 - val_loss: 1.0611 - val_accuracy: 1.0000
# Epoch 144/300
# 1/1 [==============================] - 0s 39ms/step - loss: 1.0591 - accuracy: 1.0000 - val_loss: 1.0552 - val_accuracy: 1.0000
# Epoch 145/300
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0535 - accuracy: 1.0000 - val_loss: 1.0494 - val_accuracy: 1.0000
# Epoch 146/300
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0479 - accuracy: 1.0000 - val_loss: 1.0435 - val_accuracy: 1.0000
# Epoch 147/300
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0422 - accuracy: 1.0000 - val_loss: 1.0376 - val_accuracy: 1.0000
# Epoch 148/300
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0366 - accuracy: 1.0000 - val_loss: 1.0317 - val_accuracy: 1.0000
# Epoch 149/300
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0309 - accuracy: 1.0000 - val_loss: 1.0258 - val_accuracy: 1.0000
# Epoch 150/300
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0252 - accuracy: 1.0000 - val_loss: 1.0199 - val_accuracy: 1.0000
# Epoch 151/300
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0195 - accuracy: 1.0000 - val_loss: 1.0138 - val_accuracy: 1.0000
# Epoch 152/300
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0137 - accuracy: 1.0000 - val_loss: 1.0078 - val_accuracy: 1.0000
# Epoch 153/300
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0080 - accuracy: 1.0000 - val_loss: 1.0018 - val_accuracy: 1.0000
# Epoch 154/300
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0022 - accuracy: 1.0000 - val_loss: 0.9957 - val_accuracy: 1.0000
# Epoch 155/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9964 - accuracy: 1.0000 - val_loss: 0.9897 - val_accuracy: 1.0000
# Epoch 156/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9905 - accuracy: 1.0000 - val_loss: 0.9836 - val_accuracy: 1.0000
# Epoch 157/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9847 - accuracy: 1.0000 - val_loss: 0.9775 - val_accuracy: 1.0000
# Epoch 158/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9788 - accuracy: 1.0000 - val_loss: 0.9714 - val_accuracy: 1.0000
# Epoch 159/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9730 - accuracy: 1.0000 - val_loss: 0.9651 - val_accuracy: 1.0000
# Epoch 160/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9671 - accuracy: 1.0000 - val_loss: 0.9590 - val_accuracy: 1.0000
# Epoch 161/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9611 - accuracy: 1.0000 - val_loss: 0.9528 - val_accuracy: 1.0000
# Epoch 162/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9552 - accuracy: 1.0000 - val_loss: 0.9466 - val_accuracy: 1.0000
# Epoch 163/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9492 - accuracy: 1.0000 - val_loss: 0.9404 - val_accuracy: 1.0000
# Epoch 164/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9432 - accuracy: 1.0000 - val_loss: 0.9341 - val_accuracy: 1.0000
# Epoch 165/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9372 - accuracy: 1.0000 - val_loss: 0.9278 - val_accuracy: 1.0000
# Epoch 166/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9312 - accuracy: 1.0000 - val_loss: 0.9216 - val_accuracy: 1.0000
# Epoch 167/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9252 - accuracy: 1.0000 - val_loss: 0.9152 - val_accuracy: 1.0000
# Epoch 168/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9191 - accuracy: 1.0000 - val_loss: 0.9089 - val_accuracy: 1.0000
# Epoch 169/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9130 - accuracy: 1.0000 - val_loss: 0.9024 - val_accuracy: 1.0000
# Epoch 170/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9069 - accuracy: 1.0000 - val_loss: 0.8961 - val_accuracy: 1.0000
# Epoch 171/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9008 - accuracy: 1.0000 - val_loss: 0.8897 - val_accuracy: 1.0000
# Epoch 172/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.8946 - accuracy: 1.0000 - val_loss: 0.8832 - val_accuracy: 1.0000
# Epoch 173/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.8885 - accuracy: 1.0000 - val_loss: 0.8769 - val_accuracy: 1.0000
# Epoch 174/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.8823 - accuracy: 1.0000 - val_loss: 0.8703 - val_accuracy: 1.0000
# Epoch 175/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.8761 - accuracy: 1.0000 - val_loss: 0.8638 - val_accuracy: 1.0000
# Epoch 176/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.8699 - accuracy: 1.0000 - val_loss: 0.8574 - val_accuracy: 1.0000
# Epoch 177/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.8637 - accuracy: 1.0000 - val_loss: 0.8509 - val_accuracy: 1.0000
# Epoch 178/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.8574 - accuracy: 1.0000 - val_loss: 0.8444 - val_accuracy: 1.0000
# Epoch 179/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.8512 - accuracy: 1.0000 - val_loss: 0.8378 - val_accuracy: 1.0000
# Epoch 180/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.8449 - accuracy: 1.0000 - val_loss: 0.8313 - val_accuracy: 1.0000
# Epoch 181/300
# 1/1 [==============================] - 0s 49ms/step - loss: 0.8386 - accuracy: 1.0000 - val_loss: 0.8248 - val_accuracy: 1.0000
# Epoch 182/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.8323 - accuracy: 1.0000 - val_loss: 0.8183 - val_accuracy: 1.0000
# Epoch 183/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.8260 - accuracy: 1.0000 - val_loss: 0.8118 - val_accuracy: 1.0000
# Epoch 184/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.8197 - accuracy: 1.0000 - val_loss: 0.8052 - val_accuracy: 1.0000
# Epoch 185/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.8134 - accuracy: 1.0000 - val_loss: 0.7987 - val_accuracy: 1.0000
# Epoch 186/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.8070 - accuracy: 1.0000 - val_loss: 0.7923 - val_accuracy: 1.0000
# Epoch 187/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.8007 - accuracy: 1.0000 - val_loss: 0.7857 - val_accuracy: 1.0000
# Epoch 188/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.7943 - accuracy: 1.0000 - val_loss: 0.7792 - val_accuracy: 1.0000
# Epoch 189/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.7880 - accuracy: 1.0000 - val_loss: 0.7728 - val_accuracy: 1.0000
# Epoch 190/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7816 - accuracy: 1.0000 - val_loss: 0.7663 - val_accuracy: 1.0000
# Epoch 191/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.7752 - accuracy: 1.0000 - val_loss: 0.7599 - val_accuracy: 1.0000
# Epoch 192/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7689 - accuracy: 1.0000 - val_loss: 0.7534 - val_accuracy: 1.0000
# Epoch 193/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7625 - accuracy: 1.0000 - val_loss: 0.7470 - val_accuracy: 1.0000
# Epoch 194/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.7561 - accuracy: 1.0000 - val_loss: 0.7407 - val_accuracy: 1.0000
# Epoch 195/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7498 - accuracy: 1.0000 - val_loss: 0.7344 - val_accuracy: 1.0000
# Epoch 196/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.7435 - accuracy: 1.0000 - val_loss: 0.7282 - val_accuracy: 1.0000
# Epoch 197/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7371 - accuracy: 1.0000 - val_loss: 0.7219 - val_accuracy: 1.0000
# Epoch 198/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.7308 - accuracy: 1.0000 - val_loss: 0.7156 - val_accuracy: 1.0000
# Epoch 199/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.7245 - accuracy: 1.0000 - val_loss: 0.7094 - val_accuracy: 1.0000
# Epoch 200/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7182 - accuracy: 1.0000 - val_loss: 0.7033 - val_accuracy: 1.0000
# Epoch 201/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7120 - accuracy: 1.0000 - val_loss: 0.6970 - val_accuracy: 1.0000
# Epoch 202/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.7058 - accuracy: 1.0000 - val_loss: 0.6910 - val_accuracy: 1.0000
# Epoch 203/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6996 - accuracy: 1.0000 - val_loss: 0.6851 - val_accuracy: 1.0000
# Epoch 204/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.6935 - accuracy: 1.0000 - val_loss: 0.6791 - val_accuracy: 1.0000
# Epoch 205/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6874 - accuracy: 1.0000 - val_loss: 0.6731 - val_accuracy: 1.0000
# Epoch 206/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6813 - accuracy: 1.0000 - val_loss: 0.6673 - val_accuracy: 1.0000
# Epoch 207/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6753 - accuracy: 1.0000 - val_loss: 0.6615 - val_accuracy: 1.0000
# Epoch 208/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6694 - accuracy: 1.0000 - val_loss: 0.6558 - val_accuracy: 1.0000
# Epoch 209/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6635 - accuracy: 1.0000 - val_loss: 0.6502 - val_accuracy: 1.0000
# Epoch 210/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6577 - accuracy: 1.0000 - val_loss: 0.6445 - val_accuracy: 1.0000
# Epoch 211/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6519 - accuracy: 1.0000 - val_loss: 0.6390 - val_accuracy: 1.0000
# Epoch 212/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6463 - accuracy: 1.0000 - val_loss: 0.6336 - val_accuracy: 1.0000
# Epoch 213/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6406 - accuracy: 1.0000 - val_loss: 0.6282 - val_accuracy: 1.0000
# Epoch 214/300
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6351 - accuracy: 1.0000 - val_loss: 0.6229 - val_accuracy: 1.0000
# Epoch 215/300
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6296 - accuracy: 1.0000 - val_loss: 0.6176 - val_accuracy: 1.0000
# Epoch 216/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6242 - accuracy: 1.0000 - val_loss: 0.6125 - val_accuracy: 1.0000
# Epoch 217/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6189 - accuracy: 1.0000 - val_loss: 0.6074 - val_accuracy: 1.0000
# Epoch 218/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6137 - accuracy: 1.0000 - val_loss: 0.6025 - val_accuracy: 1.0000
# Epoch 219/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6086 - accuracy: 1.0000 - val_loss: 0.5976 - val_accuracy: 1.0000
# Epoch 220/300
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6035 - accuracy: 1.0000 - val_loss: 0.5928 - val_accuracy: 1.0000
# Epoch 221/300
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5985 - accuracy: 1.0000 - val_loss: 0.5879 - val_accuracy: 1.0000
# Epoch 222/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5937 - accuracy: 1.0000 - val_loss: 0.5835 - val_accuracy: 1.0000
# Epoch 223/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5889 - accuracy: 1.0000 - val_loss: 0.5788 - val_accuracy: 1.0000
# Epoch 224/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5842 - accuracy: 1.0000 - val_loss: 0.5744 - val_accuracy: 1.0000
# Epoch 225/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5796 - accuracy: 1.0000 - val_loss: 0.5700 - val_accuracy: 1.0000
# Epoch 226/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5750 - accuracy: 1.0000 - val_loss: 0.5656 - val_accuracy: 1.0000
# Epoch 227/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5706 - accuracy: 1.0000 - val_loss: 0.5615 - val_accuracy: 1.0000
# Epoch 228/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5663 - accuracy: 1.0000 - val_loss: 0.5573 - val_accuracy: 1.0000
# Epoch 229/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5620 - accuracy: 1.0000 - val_loss: 0.5533 - val_accuracy: 1.0000
# Epoch 230/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5579 - accuracy: 1.0000 - val_loss: 0.5493 - val_accuracy: 1.0000
# Epoch 231/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5538 - accuracy: 1.0000 - val_loss: 0.5455 - val_accuracy: 1.0000
# Epoch 232/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5498 - accuracy: 1.0000 - val_loss: 0.5417 - val_accuracy: 1.0000
# Epoch 233/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5459 - accuracy: 1.0000 - val_loss: 0.5380 - val_accuracy: 1.0000
# Epoch 234/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5421 - accuracy: 1.0000 - val_loss: 0.5344 - val_accuracy: 1.0000
# Epoch 235/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5384 - accuracy: 1.0000 - val_loss: 0.5308 - val_accuracy: 1.0000
# Epoch 236/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5348 - accuracy: 1.0000 - val_loss: 0.5274 - val_accuracy: 1.0000
# Epoch 237/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.5312 - accuracy: 1.0000 - val_loss: 0.5240 - val_accuracy: 1.0000
# Epoch 238/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5277 - accuracy: 1.0000 - val_loss: 0.5207 - val_accuracy: 1.0000
# Epoch 239/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.5243 - accuracy: 1.0000 - val_loss: 0.5175 - val_accuracy: 1.0000
# Epoch 240/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5210 - accuracy: 1.0000 - val_loss: 0.5143 - val_accuracy: 1.0000
# Epoch 241/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5177 - accuracy: 1.0000 - val_loss: 0.5111 - val_accuracy: 1.0000
# Epoch 242/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5145 - accuracy: 1.0000 - val_loss: 0.5082 - val_accuracy: 1.0000
# Epoch 243/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.5113 - accuracy: 1.0000 - val_loss: 0.5052 - val_accuracy: 1.0000
# Epoch 244/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5082 - accuracy: 1.0000 - val_loss: 0.5021 - val_accuracy: 1.0000
# Epoch 245/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5052 - accuracy: 1.0000 - val_loss: 0.4993 - val_accuracy: 1.0000
# Epoch 246/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5022 - accuracy: 1.0000 - val_loss: 0.4965 - val_accuracy: 1.0000
# Epoch 247/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4992 - accuracy: 1.0000 - val_loss: 0.4937 - val_accuracy: 1.0000
# Epoch 248/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4963 - accuracy: 1.0000 - val_loss: 0.4910 - val_accuracy: 1.0000
# Epoch 249/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4935 - accuracy: 1.0000 - val_loss: 0.4884 - val_accuracy: 1.0000
# Epoch 250/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4907 - accuracy: 1.0000 - val_loss: 0.4857 - val_accuracy: 1.0000
# Epoch 251/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4879 - accuracy: 1.0000 - val_loss: 0.4831 - val_accuracy: 1.0000
# Epoch 252/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4852 - accuracy: 1.0000 - val_loss: 0.4806 - val_accuracy: 1.0000
# Epoch 253/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4825 - accuracy: 1.0000 - val_loss: 0.4781 - val_accuracy: 1.0000
# Epoch 254/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4799 - accuracy: 1.0000 - val_loss: 0.4756 - val_accuracy: 1.0000
# Epoch 255/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4773 - accuracy: 1.0000 - val_loss: 0.4732 - val_accuracy: 1.0000
# Epoch 256/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4747 - accuracy: 1.0000 - val_loss: 0.4709 - val_accuracy: 1.0000
# Epoch 257/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4722 - accuracy: 1.0000 - val_loss: 0.4685 - val_accuracy: 1.0000
# Epoch 258/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4697 - accuracy: 1.0000 - val_loss: 0.4661 - val_accuracy: 1.0000
# Epoch 259/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4672 - accuracy: 1.0000 - val_loss: 0.4640 - val_accuracy: 1.0000
# Epoch 260/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4648 - accuracy: 1.0000 - val_loss: 0.4617 - val_accuracy: 1.0000
# Epoch 261/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4624 - accuracy: 1.0000 - val_loss: 0.4593 - val_accuracy: 1.0000
# Epoch 262/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4600 - accuracy: 1.0000 - val_loss: 0.4573 - val_accuracy: 1.0000
# Epoch 263/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4576 - accuracy: 1.0000 - val_loss: 0.4550 - val_accuracy: 1.0000
# Epoch 264/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4553 - accuracy: 1.0000 - val_loss: 0.4529 - val_accuracy: 1.0000
# Epoch 265/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4530 - accuracy: 1.0000 - val_loss: 0.4509 - val_accuracy: 1.0000
# Epoch 266/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4508 - accuracy: 1.0000 - val_loss: 0.4488 - val_accuracy: 1.0000
# Epoch 267/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4485 - accuracy: 1.0000 - val_loss: 0.4466 - val_accuracy: 1.0000
# Epoch 268/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4463 - accuracy: 1.0000 - val_loss: 0.4446 - val_accuracy: 1.0000
# Epoch 269/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4441 - accuracy: 1.0000 - val_loss: 0.4425 - val_accuracy: 1.0000
# Epoch 270/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4419 - accuracy: 1.0000 - val_loss: 0.4405 - val_accuracy: 1.0000
# Epoch 271/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4398 - accuracy: 1.0000 - val_loss: 0.4386 - val_accuracy: 1.0000
# Epoch 272/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4376 - accuracy: 1.0000 - val_loss: 0.4366 - val_accuracy: 0.9773
# Epoch 273/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4355 - accuracy: 1.0000 - val_loss: 0.4346 - val_accuracy: 0.9773
# Epoch 274/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4334 - accuracy: 1.0000 - val_loss: 0.4327 - val_accuracy: 0.9773
# Epoch 275/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4313 - accuracy: 1.0000 - val_loss: 0.4308 - val_accuracy: 0.9773
# Epoch 276/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4292 - accuracy: 1.0000 - val_loss: 0.4289 - val_accuracy: 0.9773
# Epoch 277/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4272 - accuracy: 1.0000 - val_loss: 0.4269 - val_accuracy: 0.9773
# Epoch 278/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4251 - accuracy: 1.0000 - val_loss: 0.4250 - val_accuracy: 0.9773
# Epoch 279/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4231 - accuracy: 1.0000 - val_loss: 0.4232 - val_accuracy: 0.9773
# Epoch 280/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4211 - accuracy: 1.0000 - val_loss: 0.4213 - val_accuracy: 0.9773
# Epoch 281/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4191 - accuracy: 1.0000 - val_loss: 0.4194 - val_accuracy: 0.9773
# Epoch 282/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4171 - accuracy: 1.0000 - val_loss: 0.4176 - val_accuracy: 0.9773
# Epoch 283/300
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4151 - accuracy: 1.0000 - val_loss: 0.4158 - val_accuracy: 0.9773
# Epoch 284/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4132 - accuracy: 1.0000 - val_loss: 0.4139 - val_accuracy: 0.9773
# Epoch 285/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4112 - accuracy: 1.0000 - val_loss: 0.4122 - val_accuracy: 0.9773
# Epoch 286/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4093 - accuracy: 1.0000 - val_loss: 0.4103 - val_accuracy: 0.9773
# Epoch 287/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4073 - accuracy: 1.0000 - val_loss: 0.4086 - val_accuracy: 0.9773
# Epoch 288/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4054 - accuracy: 1.0000 - val_loss: 0.4067 - val_accuracy: 0.9773
# Epoch 289/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4035 - accuracy: 1.0000 - val_loss: 0.4050 - val_accuracy: 0.9773
# Epoch 290/300
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4016 - accuracy: 1.0000 - val_loss: 0.4034 - val_accuracy: 0.9773
# Epoch 291/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3997 - accuracy: 1.0000 - val_loss: 0.4015 - val_accuracy: 0.9773
# Epoch 292/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3978 - accuracy: 1.0000 - val_loss: 0.3998 - val_accuracy: 0.9773
# Epoch 293/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3959 - accuracy: 1.0000 - val_loss: 0.3981 - val_accuracy: 0.9773
# Epoch 294/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3940 - accuracy: 1.0000 - val_loss: 0.3963 - val_accuracy: 0.9773
# Epoch 295/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3921 - accuracy: 1.0000 - val_loss: 0.3945 - val_accuracy: 0.9773
# Epoch 296/300
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3902 - accuracy: 1.0000 - val_loss: 0.3928 - val_accuracy: 0.9773
# Epoch 297/300
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3884 - accuracy: 1.0000 - val_loss: 0.3911 - val_accuracy: 0.9773
# Epoch 298/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3865 - accuracy: 1.0000 - val_loss: 0.3893 - val_accuracy: 0.9773
# Epoch 299/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3846 - accuracy: 1.0000 - val_loss: 0.3876 - val_accuracy: 0.9773
# Epoch 300/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3828 - accuracy: 1.0000 - val_loss: 0.3858 - val_accuracy: 0.9773

# %%
plt.plot(history.history['accuracy'],
         label='обучающий набор')
plt.plot(history.history['val_accuracy'],
         label='проверочный набор')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()

# %% [markdown]
# # Тест моделей

# %%
def test_model(text,max_text_len = max_text_len,model=model):
    test_text = text.lower()
    data_test = tokenizer.texts_to_sequences([test_text])
    data_pad_test = pad_sequences(data_test, maxlen = max_text_len)
    res = model.predict(data_pad_test)
    return res, np.argmax(res)

# %%
test_model("""def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr""")
# Out:
# (array([[0.8546389 , 0.02518397, 0.05460317, 0.06557401]], dtype=float32), 0)

# %%
test_model("""def quicksort(arr):
        if len(arr) <= 1:
            return arr
        else:
            pivot = arr[0]
            less = [x for x in arr[1:] if x <= pivot]
            greater = [x for x in arr[1:] if x > pivot]
            return quicksort(less) + [pivot] + quicksort(greater)
            """)
# Out:
# (array([[0.15967546, 0.5317683 , 0.13943222, 0.16912399]], dtype=float32), 1)

# %%
test_model("""def selection_sort(arr):        
    for i in range(len(arr)):
        minimum = i
        for j in range(i + 1, len(arr)):
            if arr[j] < arr[minimum]:
                minimum = j
        arr[minimum], arr[i] = arr[i], arr[minimum]
    return arr""")
# Out:
# (array([[0.10486492, 0.1063995 , 0.68421334, 0.1045222 ]], dtype=float32), 2)

# %%
test_model("""import operator
def merge_sort(L, compare=operator.lt):
    if len(L) < 2:
        return L[:]
    else:
        middle = int(len(L) / 2)
        left = merge_sort(L[:middle], compare)
        right = merge_sort(L[middle:], compare)
        return merge(left, right, compare)
        
        def merge(left, right, compare):
    result = []
    i, j = 0, 0
    while i < len(left) and j < len(right):
        if compare(left[i], right[j]):
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    while i < len(left):
        result.append(left[i])
        i += 1
    while j < len(right):
        result.append(right[j])
        j += 1
    return result""")
# Out:
# (array([[0.08648505, 0.20668004, 0.07801742, 0.62881744]], dtype=float32), 3)

# %%
# model.save('models\\test_4_sort(6).h5')

# %%
# models\\test_4_sort(3).h5
# maxWord = 30
# max_text_len = 50

# %%
# models\\test_4_sort(4).h5
# maxWord = 30
# max_text_len = 100

# %%
# model.save('models\\test_4_sort(5).h5')
# maxWord = 15
# max_text_len = 30

# %%
# model.save('models\\test_4_sort(6).h5')
# maxWord = 15
# max_text_len = 40

# %% [markdown]
# # Вспомогательные функции

# %%
pwd
# Out:
# 'C:\\Users\\Matvey\\Анализ кода\\Code-Insight'

# %%
# %cd Анализ кода/Code-Insight
# Out:
# C:\Users\Matvey\Анализ кода\Code-Insight

# %%
# %cd ../..
# Out:
# C:\Users\Matvey\Анализ кода\Code-Insight\dataset

# %%
# %cd ../
# Out:
# C:\Users\Matvey\Анализ кода\Code-Insight

# %%
# %cd ../../..
