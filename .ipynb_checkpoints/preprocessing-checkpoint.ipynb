# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import os
from os import chdir

# %%
#планируется словарь алгоритмов для более быстрого создания всех датафреймов
alg_dict = {'sort': ['bubble_sort', 'quicksort'], 'find': ['binary_search']}

# %%
#создание датафрейма
def make_df():
    df = pd.read_csv(f'csv/dataset.csv')
    df = df.set_index('filename')
    del df['Unnamed: 0']
    return df

# %%
df = make_df()
df
# Out:
#                      language algorithm algorithm_name
# filename
# bubble_sort (2).py         py      sort    bubble_sort
# bubble_sort (3).py         py      sort    bubble_sort
# bubble_sort (4).py         py      sort    bubble_sort
# bubble_sort (5).py         py      sort    bubble_sort
# bubble_sort (6).py         py      sort    bubble_sort
# bubble_sort (7).py         py      sort    bubble_sort
# bubble_sort (8).py         py      sort    bubble_sort
# bubble_sort (9).py         py      sort    bubble_sort
# bubble_sort (10).py        py      sort   bubble_sort
# bubble_sort (11).py        py      sort   bubble_sort
# bubble_sort (12).py        py      sort   bubble_sort
# bubble_sort (13).py        py      sort   bubble_sort
# bubble_sort (14).py        py      sort   bubble_sort
# bubble_sort (15).py        py      sort   bubble_sort
# bubble_sort (16).py        py      sort   bubble_sort
# bubble_sort (17).py        py      sort   bubble_sort
# bubble_sort (18).py        py      sort   bubble_sort
# bubble_sort (19).py        py      sort   bubble_sort
# bubble_sort.py             py      sort    bubble_sort
# quick_sort (2).py          py      sort     quick_sort
# quick_sort (3).py          py      sort     quick_sort
# quick_sort (4).py          py      sort     quick_sort
# quick_sort (5).py          py      sort     quick_sort
# quick_sort (6).py          py      sort     quick_sort
# quick_sort (7).py          py      sort     quick_sort
# quick_sort (8).py          py      sort     quick_sort
# quick_sort (9).py          py      sort     quick_sort
# quick_sort.py              py      sort     quick_sort
# binary_search (2).py       py      find  binary_search
# binary_search (3).py       py      find  binary_search
# binary_search (4).py       py      find  binary_search
# binary_search (5).py       py      find  binary_search
# binary_search (6).py       py      find  binary_search
# binary_search (7).py       py      find  binary_search
# binary_search.py           py      find  binary_search

# %%
def file_read(df):
    new_lines = []
    #df = df.sort_values(by='filename')
    for index, row in df.iterrows():
        chdir(f'dataset/{row[1]}/{row[2]}')
        with open(str(index),'r', encoding = 'utf-8') as f:
            lines = f.readlines()
            lines = [line for line in lines if line.strip() != ""]
        # %cd ../../..
        new_lines.append(lines)
    #%cd ../..
    return new_lines

# %%
file = file_read(df)
# Out:
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight
# C:\Users\Matvey\Анализ кода\Code-Insight

# %%
file
# Out:
# [['def bubble_sort(list1):\n',
#   '    has_swapped = True\n',
#   '    total_iteration = 0\n',
#   '    while (has_swapped):\n',
#   '        has_swapped = False\n',
#   '        for i in range(len(list1) - total_iteration - 1):\n',
#   '            if list1[i] > list1[i + 1]:\n',
#   '                # Swap\n',
#   '                list1[i], list1[i + 1] = list1[i + 1], list1[i]\n',
#   '                has_swapped = True\n',
#   '        total_iteration += 1\n',
#   '    print("The number of iteraton: ", total_iteration)\n',
#   '    return list1\n'],
#  ['def bubble_sort(list1):\n',
#   '    has_swapped = True\n',
#   '    while (has_swapped):\n',
#   '        has_swapped = False\n',
#   '        for i in range(len(list1) - 1):\n',
#   '            if list1[i] > list1[i + 1]:\n',
#   '                list1[i], list1[i + 1] = list1[i + 1], list1[i]\n',
#   '                has_swapped = True\n',
#   '    return list1\n'],
#  ['def bubble_sort(list1):\n',
#   '    for i in range(0, len(list1) - 1):\n',
#   '        for j in range(len(list1) - 1):\n',
#   '            if (list1[j] > list1[j + 1]):\n',
#   '                list1[j], list1[j + 1] = list1[j + 1], list1[j]\n',
#   '    return list1\n'],
#  ['def bubble_sort(list1):\n',
#   '    for i in range(0, len(list1) - 1):\n',
#   '        for j in range(len(list1) - 1):\n',
#   '            if (list1[j] > list1[j + 1]):\n',
#   '                temp = list1[j]\n',
#   '                list1[j] = list1[j + 1]\n',
#   '                list1[j + 1] = temp\n',
#   '    return list1\n'],
#  ['def bubble(array):\n',
#   '    for i in range(N - 1):\n',
#   '        for j in range(N - i - 1):\n',
#   '            if array[j] > array[j + 1]:\n',
#   '                buff = array[j]\n',
#   '                array[j] = array[j + 1]\n',
#   '                array[j + 1] = buff\n'],
#  ['def bubble(a,N):\n',
#   '    for i in range(N - 1):\n',
#   '        for j in range(N - i - 1):\n',
#   '            if a[j] > a[j + 1]:\n',
#   '                a[j], a[j + 1] = a[j + 1], a[j]\n'],
#  ['def bubble_sort(nums):\n',
#   '    swapped = True\n',
#   '    while swapped:\n',
#   '        swapped = False\n',
#   '        for i in range(len(nums) - 1):\n',
#   '            if nums[i] > nums[i + 1]:\n',
#   '                nums[i], nums[i + 1] = nums[i + 1], nums[i]\n',
#   '                swapped = True\n'],
#  ['def bubble_sort(array):\n',
#   '    size = len(array)\n',
#   '    for i in range(size - 1):\n',
#   '        for j in range(size - 1):\n',
#   '            if array[j] > array[j + 1]:\n',
#   '                array[j], array[j + 1] = array[j + 1], array[j]\n',
#   '    return array'],
#  ['def bubble_sort(arr):\n',
#   '    n = len(arr)\n',
#   '    swapped = True\n',
#   '    while swapped:\n',
#   '        swapped = False\n',
#   '        for i in range(n-1):\n',
#   '            if arr[i] > arr[i+1]:\n',
#   '                arr[i], arr[i+1] = arr[i+1], arr[i]\n',
#   '                swapped = True\n',
#   '    return arr'],
#  ['def bubble_sort(arr):\n',
#   '    n = len(arr)\n',
#   '    last_swap = n-1\n',
#   '    while last_swap > 0:\n',
#   '        new_last_swap = 0\n',
#   '        for i in range(last_swap):\n',
#   '            if arr[i] > arr[i+1]:\n',
#   '                arr[i], arr[i+1] = arr[i+1], arr[i]\n',
#   '                new_last_swap = i\n',
#   '        last_swap = new_last_swap\n',
#   '    return arr'],
#  ['def bubble_sort(arr):\n',
#   '    n = len(arr)\n',
#   '    for i in range(n-1):\n',
#   '        is_sorted = True\n',
#   '        for j in range(n-i-1):\n',
#   '            if arr[j] > arr[j+1]:\n',
#   '                arr[j], arr[j+1] = arr[j+1], arr[j]\n',
#   '                is_sorted = False\n',
#   '        if is_sorted:\n',
#   '            break\n',
#   '        n -= 1\n',
#   '    return arr'],
#  ['def bubble_sort(arr):\n',
#   '    n = len(arr)\n',
#   '    for i in range(n-1):\n',
#   '        swaps = 0\n',
#   '        for j in range(n-i-1):\n',
#   '            if arr[j] > arr[j+1]:\n',
#   '                arr[j], arr[j+1] = arr[j+1], arr[j]\n',
#   '                swaps += 1\n',
#   '        if swaps == 0:\n',
#   '            break\n',
#   '    return arr'],
#  ['def bubble_sort_limit_passes(arr, max_passes):\n',
#   '    n = len(arr)\n',
#   '    for i in range(min(max_passes, n-1)):\n',
#   '        for j in range(n-i-1):\n',
#   '            if arr[j] > arr[j+1]:\n',
#   '                arr[j], arr[j+1] = arr[j+1], arr[j]\n',
#   '    return arr'],
#  ['def bubble_sort(arr, n=None):\n',
#   '    if n is None:\n',
#   '        n = len(arr)\n',
#   '    if n == 1:\n',
#   '        return arr\n',
#   '    for i in range(n-1):\n',
#   '        if arr[i] > arr[i+1]:\n',
#   '\t    arr[i], arr[i+1] = arr[i+1], arr[i]\n',
#   '     return bubble_sort_recursive(arr, n-1)'],
#  ['def bubble_sort_optimized(lst):\n',
#   '    length = len(lst)\n',
#   '    for i in range(length - 1):\n',
#   '        is_swapped = False\n',
#   '        for j in range(length - i - 1):\n',
#   '            if lst[j] > lst[j + 1]:\n',
#   '                lst[j], lst[j + 1] = lst[j + 1], lst[j]\n',
#   '                is_swapped = True\n',
#   '        if not is_swapped:\n',
#   '            break\n',
#   '    return lst'],
#  ['def bubble_sort_recursive(arr, n=None):\n',
#   '    if n is None:\n',
#   '        n = len(arr)\n',
#   '    if n == 1:\n',
#   '        return arr\n',
#   '    for i in range(n - 1):\n',
#   '        if arr[i] > arr[i + 1]:\n',
#   '            arr[i], arr[i + 1] = arr[i + 1], arr[i]\n',
#   '    return bubble_sort_recursive(arr, n - 1)'],
#  ['def bubble_sort_custom_key(arr, comparison_key=lambda x: x):\n',
#   '    length = len(arr)\n',
#   '    for i in range(length - 1):\n',
#   '        for j in range(length - i - 1):\n',
#   '            if comparison_key(arr[j]) > comparison_key(arr[j + 1]):\n',
#   '                arr[j], arr[j + 1] = arr[j + 1], arr[j]\n',
#   '    return arr'],
#  ['def bubble_sort(arr):\n',
#   '    n = len(arr)\n',
#   '    for i in range(n-1):\n',
#   '        is_sorted = True\n',
#   '        for j in range(n-i-1):\n',
#   '            if arr[j] > arr[j+1]:\n',
#   '                arr[j], arr[j+1] = arr[j+1], arr[j]\n',
#   '                is_sorted = False\n',
#   '        if is_sorted:\n',
#   '            break\n',
#   '    return arr'],
#  ['def bubble(a,N):\n',
#   '    i = 0\n',
#   '    while i < N - 1:\n',
#   '        j = 0\n',
#   '        while j < N - 1 - i:\n',
#   '            if a[j] > a[j + 1]:\n',
#   '                a[j], a[j + 1] = a[j + 1], a[j]\n',
#   '            j += 1\n',
#   '        i += 1\n'],
#  ['def quick_sort(arr):\n',
#   '    if len(arr) <= 1:\n',
#   '        return arr\n',
#   '    pivot = arr[len(arr) // 2]\n',
#   '    less = []\n',
#   '    equal = []\n',
#   '    more = []\n',
#   '    for num in arr:\n',
#   '        if num < pivot:\n',
#   '            less.append(num)\n',
#   '        elif num == pivot:\n',
#   '            equal.append(num)\n',
#   '        else:\n',
#   '            more.append(num)\n',
#   '    return quick_sort(less) + equal + quick_sort(more)'],
#  ['def quick_sort(arr):\n',
#   '    if len(arr) <= 1:\n',
#   '        return arr\n',
#   '    pivot = arr[0]\n',
#   '    i = 1\n',
#   '    j = len(arr) - 1\n',
#   '    while True:\n',
#   '        while i <= j and arr[i] <= pivot:\n',
#   '            i += 1\n',
#   '        while i <= j and arr[j] >= pivot:\n',
#   '            j -= 1\n',
#   '        if i <= j:\n',
#   '            arr[i], arr[j] = arr[j], arr[i]\n',
#   '        else:\n',
#   '            break\n',
#   '    arr[0], arr[j] = arr[j], arr[0]\n',
#   '    return quick_sort(arr[:j]) + [arr[j]] + quick_sort(arr[j + 1:])'],
#  ['def quick_sort(arr):\n',
#   '    if len(arr) <= 1:\n',
#   '        return arr\n',
#   '    stack = [(0, len(arr) - 1)]\n',
#   '    while stack:\n',
#   '        start, end = stack.pop()\n',
#   '        if start >= end:\n',
#   '            continue\n',
#   '        pivot = arr[start]\n',
#   '        i = start + 1\n',
#   '        j = end\n',
#   '        while True:\n',
#   '            while i <= j and arr[i] <= pivot:\n',
#   '                i += 1\n',
#   '            while i <= j and arr[j] >= pivot:\n',
#   '                j -= 1\n',
#   '            if i <= j:\n',
#   '                arr[i], arr[j] = arr[j], arr[i]\n',
#   '            else:\n',
#   '                break\n',
#   '        arr[start], arr[j] = arr[j], arr[start]\n',
#   '        stack.append((start, j - 1))\n',
#   '        stack.append((j + 1, end))\n',
#   '    return arr'],
#  ['import random\n',
#   'def quick_sort(arr):\n',
#   '    if len(arr) <= 1:\n',
#   '        return arr\n',
#   '    pivot = random.choice(arr)\n',
#   '    left = [x for x in arr if x < pivot]\n',
#   '    middle = [x for x in arr if x == pivot]\n',
#   '    right = [x for x in arr if x > pivot]\n',
#   '    return quick_sort_random_pivot(left) + middle + quick_sort_random_pivot(right)'],
#  ['def quick_sort(arr):\n',
#   '    if len(arr) <= 1:\n',
#   '        return arr\n',
#   '    pivot = arr[len(arr) // 2]\n',
#   '    i = 0\n',
#   '    j = len(arr) - 1\n',
#   '    while i <= j:\n',
#   '        while arr[i] < pivot:\n',
#   '            i += 1\n',
#   '        while arr[j] > pivot:\n',
#   '            j -= 1\n',
#   '        if i <= j:\n',
#   '            arr[i], arr[j] = arr[j], arr[i]\n',
#   '            i += 1\n',
#   '            j -= 1\n',
#   '    return quick_sort_hoare(arr[:i]) + quick_sort_hoare(arr[i:])\n'],
#  ['def quick_sort(arr):\n',
#   '    stack = [(0, len(arr) - 1)]\n',
#   '    while stack:\n',
#   '        low, high = stack.pop()\n',
#   '        if low < high:\n',
#   '            pivot_index = partition(arr, low, high)\n',
#   '            stack.append((low, pivot_index - 1))\n',
#   '            stack.append((pivot_index + 1, high))\n',
#   '    return arr\n',
#   'def partition(arr, low, high):\n',
#   '    pivot = arr[high]\n',
#   '    i = low - 1\n',
#   '    for j in range(low, high):\n',
#   '        if arr[j] < pivot:\n',
#   '            i += 1\n',
#   '            arr[i], arr[j] = arr[j], arr[i]\n',
#   '    arr[i + 1], arr[high] = arr[high], arr[i + 1]\n',
#   '    return i + 1'],
#  ['def quick_sort(arr, ascending=True):\n',
#   '    if len(arr) <= 1:\n',
#   '        return arr\n',
#   '    pivot = arr[len(arr) // 2]\n',
#   '    left = [x for x in arr if x < pivot]\n',
#   '    middle = [x for x in arr if x == pivot]\n',
#   '    right = [x for x in arr if x > pivot]\n',
#   '    if ascending:\n',
#   '        return quick_sort(left, ascending) + middle + quick_sort(right, ascending)\n',
#   '    else:\n',
#   '        return quick_sort(right, ascending) + middle + quick_sort(left, ascending)'],
#  ['def quick_sort(arr):\n',
#   '    if len(arr) <= 1:\n',
#   '        return arr\n',
#   '    pivot = arr[len(arr) // 2]\n',
#   '    left = [x for x in arr if x < pivot]\n',
#   '    middle = [x for x in arr if x == pivot]\n',
#   '    right = [x for x in arr if x > pivot]\n',
#   '    return quick_sort(left) + middle + quick_sort(right)'],
#  ['def quick_sort(arr):\n',
#   '    if len(arr) <= 1:\n',
#   '        return arr\n',
#   '    pivot = arr[len(arr) // 2]\n',
#   '    left = [x for x in arr if x < pivot]\n',
#   '    middle = [x for x in arr if x == pivot]\n',
#   '    right = [x for x in arr if x > pivot]\n',
#   '    return quick_sort(left) + middle + quick_sort(right)'],
#  ['def binary_search(arr, target):\n',
#   '    low = 0\n',
#   '    high = len(arr) - 1\n',
#   '    while low <= high:\n',
#   '        mid = (low + high) // 2\n',
#   '        if arr[mid][0] == target:\n',
#   '            return arr[mid][1]\n',
#   '        elif arr[mid][0] < target:\n',
#   '            low = mid + 1\n',
#   '        else:\n',
#   '            high = mid - 1\n',
#   '    return -1'],
#  ['def binary_search(arr, target, comp):\n',
#   '    low = 0\n',
#   '    high = len(arr) - 1\n',
#   '    while low <= high:\n',
#   '        mid = (low + high) // 2\n',
#   '        if comp(arr[mid], target) == 0:\n',
#   '            return mid\n',
#   '        elif comp(arr[mid], target) < 0:\n',
#   '            low = mid + 1\n',
#   '        else:\n',
#   '            high = mid - 1\n',
#   '    return -1'],
#  ['def binary_search(arr, target):\n',
#   '    low = 0\n',
#   '    high = len(arr) - 1\n',
#   '    while low <= high:\n',
#   '        mid = (low + high) // 2\n',
#   '        if arr[mid][0] == target:\n',
#   '            return mid\n',
#   '        elif arr[mid][0] < target:\n',
#   '            low = mid + 1\n',
#   '        else:\n',
#   '            high = mid - 1\n',
#   '    return -1'],
#  ['def binary_search(arr, target):\n',
#   '    low = 0\n',
#   '    high = len(arr) - 1\n',
#   '    while low <= high:\n',
#   '        mid = (low + high) // 2\n',
#   '        if arr[mid] == target:\n',
#   '            return mid\n',
#   '        elif arr[mid] < target:\n',
#   '            low = mid + 1\n',
#   '        else:\n',
#   '            high = mid - 1\n',
#   '    return -1'],
#  ['def binary_search(arr, target):\n',
#   '    low = 0\n',
#   '    high = len(arr) - 1\n',
#   '    if arr[low] > target or arr[high] < target:\n',
#   '        return -1\n',
#   '    while low <= high:\n',
#   '        mid = (low + high) // 2\n',
#   '        if arr[mid] == target:\n',
#   '            return mid\n',
#   '        elif arr[mid] < target:\n',
#   '            low = mid + 1\n',
#   '        else:\n',
#   '            high = mid - 1\n',
#   '    return -1'],
#  ['def binary_search(arr, target):\n',
#   '    low = 0\n',
#   '    high = len(arr) - 1\n',
#   '    while low <= high:\n',
#   '        mid = (low + high) // 2\n',
#   '        if arr[mid] == target:\n',
#   '            while mid > 0 and arr[mid-1] == target:\n',
#   '                mid -= 1\n',
#   '            return mid\n',
#   '        elif arr[mid] < target:\n',
#   '            low = mid + 1\n',
#   '        else:\n',
#   '            high = mid - 1\n',
#   '    return -1'],
#  ['def binary_search(arr, target):\n',
#   '    low = 0\n',
#   '    high = len(arr) - 1\n',
#   '    while low <= high:\n',
#   '        mid = (low + high) // 2\n',
#   '        if arr[mid] == target:\n',
#   '            return mid\n',
#   '        elif arr[mid] < target:\n',
#   '            low = mid + 1\n',
#   '        else:\n',
#   '            high = mid - 1\n',
#   '    return -1']]

# %%
#обработка переменной без табов, заменяя их на 2 пробела (Доработать)
def preporcessing_file(lines):
    new_lines = []
    code_line = ''
    for i in lines:
        for j in i:
            j = j.replace('    ',' ')
            code_line +=j+''
            new_lines.append(code_line)
        code_line = ''
    return new_lines

# %%
file = preporcessing_file(file)

# %% [markdown]
# # Вспомогательные функции

# %%
pwd
# Out:
# 'C:\\Users\\Matvey\\Анализ кода\\Code-Insight\\dataset'

# %%
# %cd Анализ кода/Code-Insight
# Out:
# C:\Users\Matvey\Анализ кода\Code-Insight

# %%
# %cd ../..
# Out:
# C:\Users\Matvey\Анализ кода\Code-Insight

# %%
# %cd ../

# %%
# %cd ../../..
